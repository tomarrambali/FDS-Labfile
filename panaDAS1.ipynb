# %% [markdown]
# <a href="https://colab.research.google.com/github/tomarrambali/FDS-Labfile/blob/main/panaDAS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Write a Pandas program to create a dataframe from a dictionary and display
# it.
# Sample data: {&#39;X&#39;:[78,85,96,80,86], &#39;Y&#39;:[84,94,89,83,86],&#39;Z&#39;:[86,97,96,72,83]}

# %%
import  pandas as pd
import  numpy as np
sample_data = {
    'X':[78,85,96,80,86],
    'y':[21,24,52,85,52],
    'z':[85,52,56,22,55],
}
label =['a','b','c','d','e']
df = pd.DataFrame(sample_data, index = label)
df
# Out:
#     X   y   z
# a  78  21  85
# b  85  24  52
# c  96  52  56
# d  80  85  22
# e  86  52  55
#     X   y   z
# a  78  21  85
# b  85  24  52
# c  96  52  56
# d  80  85  22
# e  86  52  55

# %% [markdown]
# 2. Write a Pandas program to create and display a DataFrame from a specified
# dictionary data which has the index labels.
# Sample Python dictionary data and list labels:
# exam_data = {&#39;name&#39;: [&#39;Anastasia&#39;, &#39;Dima&#39;, &#39;Katherine&#39;, &#39;James&#39;, &#39;Emily&#39;,
# &#39;Michael&#39;, &#39;Matthew&#39;, &#39;Laura&#39;, &#39;Kevin&#39;, &#39;Jonas&#39;],
# &#39;score&#39;: [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# &#39;attempts&#39;: [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# &#39;qualify&#39;: [&#39;yes&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;]}
# labels = [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;f&#39;, &#39;g&#39;, &#39;h&#39;, &#39;i&#39;, &#39;j&#39;]

# %%
import pandas as  pd
import numpy as np
exam_data  = {
    'Name':['sheetal','rani','siyanshi','himanshu','divyansh','avika','heena'],
    'score':[89,82,99,22,98,94,np.nan],
    'attempt':[1,2,5,8,2,1,1],
    'qualify':['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', ],

}
label=['a','b','c','d','e','f','g']
result = pd.DataFrame(exam_data,index=label)
result
# Out:
#        Name  score  attempt qualify
# a   sheetal   89.0        1     yes
# b      rani   82.0        2      no
# c  siyanshi   99.0        5     yes
# d  himanshu   22.0        8      no
# e  divyansh   98.0        2      no
# f     avika   94.0        1     yes
# g     heena    NaN        1     yes

# %% [markdown]
# 3. Write a Pandas program to get the first 3 rows of a given DataFrame.
# Sample Python dictionary data and list labels:
# exam_data = {&#39;name&#39;: [&#39;Anastasia&#39;, &#39;Dima&#39;, &#39;Katherine&#39;, &#39;James&#39;, &#39;Emily&#39;,
# &#39;Michael&#39;, &#39;Matthew&#39;, &#39;Laura&#39;, &#39;Kevin&#39;, &#39;Jonas&#39;],
# &#39;score&#39;: [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# &#39;attempts&#39;: [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# &#39;qualify&#39;: [&#39;yes&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;]}
# labels = [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;f&#39;, &#39;g&#39;, &#39;h&#39;, &#39;i&#39;, &#39;j&#39;]

# %%
import pandas as pd
import numpy as np
my_data = {
    'name':['abvvi','safoia','saara','sanu','savita','shuhani','santoshi','chutiya','anamika','arrrohi'],
    'score':[89,78,25,35,98,78,52,np.nan,92,78],
    'age':[26,26,23,18,15,23,24,32,25,32],
    'attempt':[1,2,8,5,2,3,2,3,2,1],
    'qalify':['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],

}
# Out:
#        name  score  age  attempt qalify
# a     abvvi   89.0   26        1    yes
# b    safoia   78.0   26        2     no
# c     saara   25.0   23        8    yes
# d      sanu   35.0   18        5     no
# e    savita   98.0   15        2     no
# f   shuhani   78.0   23        3    yes
# g  santoshi   52.0   24        2    yes
# h   chutiya    NaN   32        3     no
# i   anamika   92.0   25        2     no
# j   arrrohi   78.0   32        1    yes
#        name  score  age  attempt qalify
# e    savita   98.0   15        2     no
# f   shuhani   78.0   23        3    yes
# g  santoshi   52.0   24        2    yes
# h   chutiya    NaN   32        3     no

# %%
import pandas as pd
import numpy as np
my_data = {
    'name':['abvvi','safoia','saara','sanu','savita','shuhani','santoshi','chutiya','anamika','arrrohi'],
    'score':[89,78,25,35,98,78,52,np.nan,92,78],
    'age':[26,26,23,18,15,23,24,32,25,32],
    'attempt':[1,2,8,5,2,3,2,3,2,1],
    'qalify':['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],

}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
result = pd.DataFrame(my_data ,index=labels)
print(result)

row1 = result.iloc[[4, 5, 6, 7]]
print(row1)
# Out:
#        name  score  age  attempt qalify
# a     abvvi   89.0   26        1    yes
# b    safoia   78.0   26        2     no
# c     saara   25.0   23        8    yes
# d      sanu   35.0   18        5     no
# e    savita   98.0   15        2     no
# f   shuhani   78.0   23        3    yes
# g  santoshi   52.0   24        2    yes
# h   chutiya    NaN   32        3     no
# i   anamika   92.0   25        2     no
# j   arrrohi   78.0   32        1    yes
#        name  score  age  attempt qalify
# e    savita   98.0   15        2     no
# f   shuhani   78.0   23        3    yes
# g  santoshi   52.0   24        2    yes
# h   chutiya    NaN   32        3     no

# %%
# importing the module
import pandas as pd

# creating a sample dataframe
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
							'Mahindra', 'Maruti', 'Hyundai',
							'Renault', 'Tata', 'Maruti'],
					'Year': [2012, 2014, 2011, 2015, 2012,
							2016, 2014, 2018, 2019],
					'Kms Driven': [50000, 30000, 60000,
									25000, 10000, 46000,
									31000, 15000, 12000],
					'City': ['Gurgaon', 'Delhi', 'Mumbai',
							'Delhi', 'Mumbai', 'Delhi',
							'Mumbai', 'Chennai', 'Ghaziabad'],
					'Mileage': [28, 27, 25, 26, 28,
								29, 24, 21, 24]})

# displaying the DataFrame
display(data)
# selecting cars with brand 'Maruti' and Mileage > 25
display(data.loc[(data.Brand == 'Maruti') & (data.Mileage > 25)])
# selecting range of rows from 2 to 5
display(data.loc[2: 5])
# updating values of Mileage if Year < 2015
data.loc[(data.Year < 2015), ['Mileage']] = 22
display(data)
# selecting 0th, 2nd, 4th, and 7th index rows
display(data.iloc[[0, 2, 4, 7]])
# selecting rows from 1 to 4 and columns from 2 to 4
display(data.iloc[1: 5, 2: 5])
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28
#       Brand  Year  Kms Driven    City  Mileage
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29
#       Brand  Year  Kms Driven       City  Mileage
# ...

# %% [markdown]
# 4.  Write a Pandas program to select the &#39;name&#39; and &#39;score&#39; columns from the
# following DataFrame.
# Sample Python dictionary data and list labels:
# exam_data = {&#39;name&#39;: [&#39;Anastasia&#39;, &#39;Dima&#39;, &#39;Katherine&#39;, &#39;James&#39;, &#39;Emily&#39;,
# &#39;Michael&#39;, &#39;Matthew&#39;, &#39;Laura&#39;, &#39;Kevin&#39;, &#39;Jonas&#39;],
# &#39;score&#39;: [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# &#39;attempts&#39;: [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# &#39;qualify&#39;: [&#39;yes&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;]}&#39;qualify&#39;: [&#39;yes&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;, &#39;yes&#39;, &#39;no&#39;, &#39;no&#39;, &#39;yes&#39;]}

# %%
import pandas as pd
import numpy as np

exam_data = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']})
display( exam_data)
display(exam_data.score)
#Select Multiple Rows and Columns
result = exam_data.loc[:,['name' ,'qualify']]
print(result)
#Select Between Two Rows or Column
result = exam_data.loc[ :, 'score' : 'qualify']
display(result)
#elect Alternate Rows or Columns
#Select Alternate Rows
alternate_rows = exam_data.iloc[::1]
display (alternate_rows)
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes
# 0    12.5
# 1     9.0
# 2    16.5
# 3     NaN
# 4     9.0
# 5    20.0
# 6    14.5
# 7     NaN
# 8     8.0
# 9    19.0
# Name: score, dtype: float64
#         name qualify
# 0  Anastasia     yes
# 1       Dima      no
# 2  Katherine     yes
# 3      James      no
# 4      Emily      no
# 5    Michael     yes
# 6    Matthew     yes
# 7      Laura      no
# 8      Kevin      no
# 9      Jonas     yes
#    score  attempts qualify
# 0   12.5         1     yes
# 1    9.0         3      no
# 2   16.5         2     yes
# 3    NaN         3      no
# ...
